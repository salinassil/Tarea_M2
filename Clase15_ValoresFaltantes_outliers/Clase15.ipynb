# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("empleados_NA_1.csv",sep=";", header=None)

# %%
df
# Out:
#    0       1          2     3
# 0  1     Ana         IT  1200
# 1  2    Luis     Ventas  1000
# 2  3      na         IT  1300
# 3  4   Pedro  Marketing  1100
# 4  5     NaN     Ventas  1050
# 5  6  Carlos         IT  1400
# 6  7     NaN  Marketing  1150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      int64
#  1   1       5 non-null      object
#  2   2       7 non-null      object
#  3   3       7 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes

# %%
df.isnull()
# Out:
#        0      1      2      3
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False   True  False  False
# 5  False  False  False  False
# 6  False   True  False  False

# %%
df.isnull().sum()
# Out:
# 0    0
# 1    2
# 2    0
# 3    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# 0     0.000000
# 1    28.571429
# 2     0.000000
# 3     0.000000
# dtype: float64

# %%
df.dropna(thresh=4)
# Out:
#    0       1          2     3
# 0  1     Ana         IT  1200
# 1  2    Luis     Ventas  1000
# 2  3      na         IT  1300
# 3  4   Pedro  Marketing  1100
# 5  6  Carlos         IT  1400

# %%
df
# Out:
#    0       1          2     3
# 0  1     Ana         IT  1200
# 1  2    Luis     Ventas  1000
# 2  3      na         IT  1300
# 3  4   Pedro  Marketing  1100
# 4  5     NaN     Ventas  1050
# 5  6  Carlos         IT  1400
# 6  7     NaN  Marketing  1150

# %%
df["Edad"]=[20,25,np.nan,30,35,60,19]

# %%
df
# Out:
#    0       1          2     3  Edad
# 0  1     Ana         IT  1200  20.0
# 1  2    Luis     Ventas  1000  25.0
# 2  3      na         IT  1300   NaN
# 3  4   Pedro  Marketing  1100  30.0
# 4  5     NaN     Ventas  1050  35.0
# 5  6  Carlos         IT  1400  60.0
# 6  7     NaN  Marketing  1150  19.0

# %%
df["Edad"].median()
# Out:
# 27.5

# %%
df["Edad"].mean()
# Out:
# np.float64(31.5)

# %%
[20,25,np.nan,30,35,60,19]

# %%
(20+25+30+35+100+19)/6
# Out:
# 38.166666666666664

# %%
19,20,25,30,35,100

# %%
(25+30)/2
# Out:
# 27.5

# %%
df["Edad"].fillna(df["Edad"].median(), inplace=True)
# Out:
# /tmp/ipython-input-194904149.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Edad"].fillna(df["Edad"].median(), inplace=True)

# %%
df
# Out:
#    0       1          2     3  Edad
# 0  1     Ana         IT  1200  20.0
# 1  2    Luis     Ventas  1000  25.0
# 2  3      na         IT  1300  27.5
# 3  4   Pedro  Marketing  1100  30.0
# 4  5     NaN     Ventas  1050  35.0
# 5  6  Carlos         IT  1400  60.0
# 6  7     NaN  Marketing  1150  19.0

# %%
df.iloc[1,2]=np.nan

# %%
df
# Out:
#    0       1          2     3  Edad
# 0  1     Ana         IT  1200  20.0
# 1  2    Luis        NaN  1000  25.0
# 2  3      na         IT  1300  27.5
# 3  4   Pedro  Marketing  1100  30.0
# 4  5     NaN     Ventas  1050  35.0
# 5  6  Carlos         IT  1400  60.0
# 6  7     NaN  Marketing  1150  19.0

# %%
df[2].mode()
# Out:
# 0    IT
# Name: 2, dtype: object

# %%
df[2].fillna(df[2].mode()[0], inplace=True)

# %%
df
# Out:
#    0       1          2     3  Edad
# 0  1     Ana         IT  1200  20.0
# 1  2    Luis         IT  1000  25.0
# 2  3      na         IT  1300  27.5
# 3  4   Pedro  Marketing  1100  30.0
# 4  5     NaN     Ventas  1050  35.0
# 5  6  Carlos         IT  1400  60.0
# 6  7     NaN  Marketing  1150  19.0

# %%
df[2].fillna("No responde", inplace=True)
# Out:
# /tmp/ipython-input-2258595884.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[2].fillna("No responde", inplace=True)

# %%
df
# Out:
#    0       1            2     3  Edad
# 0  1     Ana           IT  1200  20.0
# 1  2    Luis  No responde  1000  25.0
# 2  3      na           IT  1300  27.5
# 3  4   Pedro    Marketing  1100  30.0
# 4  5     NaN       Ventas  1050  35.0
# 5  6  Carlos           IT  1400  60.0
# 6  7     NaN    Marketing  1150  19.0

# %%
df.iloc[2,3]=np.nan

# %%
df
# Out:
#    0       1            2       3  Edad
# 0  1     Ana           IT  1200.0  20.0
# 1  2    Luis  No responde  1000.0  25.0
# 2  3      na           IT     NaN  27.5
# 3  4   Pedro    Marketing  1100.0  30.0
# 4  5     NaN       Ventas  1050.0  35.0
# 5  6  Carlos           IT  1400.0  60.0
# 6  7     NaN    Marketing  1150.0  19.0

# %%
df[3].median()
# Out:
# 1125.0

# %%
s=df.groupby(2)[3].median()

# %%
s
# Out:
# 2
# IT             1300.0
# Marketing      1125.0
# No responde    1000.0
# Ventas         1050.0
# Name: 3, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x=df["Edad"])
# Out:
# <Axes: xlabel='Edad'>

# %%
Q1=df["Edad"].quantile(0.25)
Q1
# Out:
# np.float64(22.5)

# %%
Q2=df["Edad"].quantile(0.50)
Q2
# Out:
# np.float64(27.5)

# %%
Q3=df["Edad"].quantile(0.75)
Q3
# Out:
# np.float64(32.5)

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(10.0)

# %%
Q1-1.5*IQR
# Out:
# np.float64(7.5)

# %%
df["Edad"].min()
# Out:
# 19.0

# %%
Q3+1.5*IQR
# Out:
# np.float64(47.5)

# %%
data=df[(df["Edad"]>=Q1-1.5*IQR) & (df["Edad"]<=Q3+1.5*IQR)]

# %%
data
# Out:
#    0      1            2       3  Edad
# 0  1    Ana           IT  1200.0  20.0
# 1  2   Luis  No responde  1000.0  25.0
# 2  3     na           IT     NaN  27.5
# 3  4  Pedro    Marketing  1100.0  30.0
# 4  5    NaN       Ventas  1050.0  35.0
# 6  7    NaN    Marketing  1150.0  19.0
