# %%
# Cargar las librerias que se usaran
import pandas as pd
import numpy as np

# %%
lista=[2,3,4]

# %%
lista
# Out:
# [2, 3, 4]

# %%
a=np.array([1,2,3])
a
# Out:
# [1 2 3]

# %%
# Obtener los datos
df=pd.read_csv("/content/empleados.csv")

# %%
df
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3      María           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5      Sofía       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7      Lucía    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
ht=pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
ht
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    id_empleado nombre departamento  salario
# 0            1    Ana           IT     1200
# 1            2   Luis       Ventas     1000
# 2            3  María           IT     1300
# 3            4  Pedro    Marketing     1100
# 4            5  Sofía       Ventas     1050

# %%
df.tail()
# Out:
#    id_empleado     nombre departamento  salario
# 5            6     Carlos           IT     1400
# 6            7      Lucía    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df1=pd.read_csv("empleados_dot.csv",sep=';')

# %%
df1
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3      María           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5      Sofía       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7      Lucía    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
print(df1)
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3      María           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5      Sofía       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7      Lucía    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df.columns
# Out:
# Index(['id_empleado', 'nombre', 'departamento', 'salario'], dtype='object')

# %%
df2=pd.read_csv("empleados_sh.csv",sep=';',header=None,names=['id_empleado','nombre','departamento','salario'])

# %%
df2
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3      María           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5      Sofía       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7      Lucía    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df3=pd.read_csv("empleados_NA.csv",sep=';',header=None,names=['id_empleado','nombre','departamento','salario'])

# %%
df3
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3        NaN           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5        NaN       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7        NaN    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_empleado   10 non-null     int64
#  1   nombre        7 non-null      object
#  2   departamento  10 non-null     object
#  3   salario       10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df4=pd.read_csv("empleados_NA_1.csv",sep=';',header=None,names=['id_empleado','nombre','departamento','salario'],na_values=['na'])

# %%
df4
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3        NaN           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5        NaN       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7        NaN    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_empleado   10 non-null     int64
#  1   nombre        7 non-null      object
#  2   departamento  10 non-null     object
#  3   salario       10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df4['nombre'] = df4['nombre'].fillna('Leonardo')
df4
# Out:
#    id_empleado     nombre departamento  salario
# 0            1        Ana           IT     1200
# 1            2       Luis       Ventas     1000
# 2            3   Leonardo           IT     1300
# 3            4      Pedro    Marketing     1100
# 4            5   Leonardo       Ventas     1050
# 5            6     Carlos           IT     1400
# 6            7   Leonardo    Marketing     1150
# 7            8      Jorge       Ventas      980
# 8            9  Valentina           IT     1500
# 9           10      Diego    Marketing     1080

# %%
df4.to_csv('empleados_modificado.csv', index=False)

# %%
ventas=pd.read_excel("ventas.xlsx")

# %%
ventas
# Out:
#    id_empleado  region  ventas_mensuales
# 0            1   Norte              5000
# 1            2     Sur              4200
# 2            3   Norte              6100
# 3            4  Centro              4800
# 4            5     Sur              4500
# 5            6  Centro              7000
# 6            7   Norte              5200
# 7            8     Sur              4300
# 8            9  Centro              7500
# 9           10   Norte              4900

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_empleado       10 non-null     int64
#  1   region            10 non-null     object
#  2   ventas_mensuales  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
ventas['log_ventas_mensuales'] = np.log(ventas['ventas_mensuales'])
ventas
# Out:
#    id_empleado  region  ventas_mensuales  log_ventas_mensuales
# 0            1   Norte              5000              8.517193
# 1            2     Sur              4200              8.342840
# 2            3   Norte              6100              8.716044
# 3            4  Centro              4800              8.476371
# 4            5     Sur              4500              8.411833
# 5            6  Centro              7000              8.853665
# 6            7   Norte              5200              8.556414
# 7            8     Sur              4300              8.366370
# 8            9  Centro              7500              8.922658
# 9           10   Norte              4900              8.496990

# %%
ventas2=pd.read_excel("ventas.xlsx",sheet_name="Ventas_2026")

# %%
ventas2
# Out:
#    id_empleado  region  ventas_mensuales
# 0            1   Norte              5000
# 1            2     Sur              4200
# 2            3   Norte              6100
# 3            4  Centro              4800

# %%
url=r"https://es.wikipedia.org/wiki/Regiones_de_Chile"
tablas=pd.read_html(url, storage_options={'User-Agent': 'Mozilla/5.0'})
print(f"Number of tables found: {len(tablas)}")
# Out:
# Number of tables found: 5

# %%
tablas[3]
# Out:
#     Bandera                                             Región  \
# 0       NaN                       Región de Arica y Parinacota
# 1       NaN                                 Región de Tarapacá
# 2       NaN                              Región de Antofagasta
# 3       NaN                                  Región de Atacama
# 4       NaN                                 Región de Coquimbo
# 5       NaN                               Región de Valparaíso
# 6       NaN                   Región Metropolitana de Santiago
# 7       NaN   Región del Libertador General Bernardo O'Higgins
# 8       NaN                                   Región del Maule
# 9       NaN                                    Región de Ñuble
# 10      NaN                                  Región del Biobío
# 11      NaN                             Región de La Araucanía
# 12      NaN                                 Región de Los Ríos
# 13      NaN                                Región de Los Lagos
# ...

# %%
regiones=tablas[3]

# %%
regiones
# Out:
#     Bandera                                             Región  \
# 0       NaN                       Región de Arica y Parinacota
# 1       NaN                                 Región de Tarapacá
# 2       NaN                              Región de Antofagasta
# 3       NaN                                  Región de Atacama
# 4       NaN                                 Región de Coquimbo
# 5       NaN                               Región de Valparaíso
# 6       NaN                   Región Metropolitana de Santiago
# 7       NaN   Región del Libertador General Bernardo O'Higgins
# 8       NaN                                   Región del Maule
# 9       NaN                                    Región de Ñuble
# 10      NaN                                  Región del Biobío
# 11      NaN                             Región de La Araucanía
# 12      NaN                                 Región de Los Ríos
# 13      NaN                                Región de Los Lagos
# ...

# %%
regiones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bandera                0 non-null      float64
#  1   Región                 16 non-null     object
#  2   Abreviatura Nacional   16 non-null     object
#  3   Población (2024) [8]​  16 non-null     object
#  4   Superficie (km²)       16 non-null     object
#  5   Densidad (hab./km²)    16 non-null     float64
#  6   Capital                16 non-null     object
#  7   Mapa                   0 non-null      float64
# dtypes: float64(3), object(5)
# memory usage: 1.1+ KB

# %%
url=r'https://es.wikipedia.org/wiki/Regiones_de_Chile'
tablas=pd.read_html(url, storage_options={'User-Agent': 'Mozilla/5.0'})
print(f"Number of tables found: {len(tablas)}")
